# %%
import os
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt

# %%
test_base_path = '/w/246/gzk/Task5-examples/'

# %%
c1moving = nb.load(os.path.join(test_base_path, 'c1moving.nii')).get_data()
c1moving.shape
# Out:
# /tmp/ipykernel_58631/2092236373.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   c1moving = nb.load(os.path.join(test_base_path, 'c1moving.nii')).get_data()
# (512, 512, 78)

# %%
plt.figure(figsize=(6, 6))
plt.imshow(c1moving[:, :, 34].T)
print(np.unique(c1moving))
# Out:
# [0.         0.00392157 0.00784314 0.01176471 0.01568628 0.01960784
#  0.02352941 0.02745098 0.03137255 0.03529412 0.03921569 0.04313726
#  0.04705883 0.0509804  0.05490196 0.05882353 0.0627451  0.06666667
#  0.07058824 0.07450981 0.07843138 0.08235295 0.08627451 0.09019608
#  0.09411765 0.09803922 0.10196079 0.10588236 0.10980393 0.1137255
#  0.11764707 0.12156863 0.1254902  0.12941177 0.13333334 0.13725491
#  0.14117648 0.14509805 0.14901962 0.15294119 0.15686275 0.16078432
#  0.16470589 0.16862746 0.17254903 0.1764706  0.18039217 0.18431374
#  0.18823531 0.19215687 0.19607844 0.20000001 0.20392158 0.20784315
#  0.21176472 0.21568629 0.21960786 0.22352942 0.22745099 0.23137256
#  0.23529413 0.2392157  0.24313727 0.24705884 0.25098041 0.25490198
#  0.25882354 0.26274511 0.26666668 0.27058825 0.27450982 0.27843139
#  0.28235296 0.28627453 0.2901961  0.29411766 0.29803923 0.3019608
#  0.30588237 0.30980394 0.31372551 0.31764708 0.32156865 0.32549022
# ...

# %%
c2moving = nb.load(os.path.join(test_base_path, 'c2moving.nii')).get_data()
c2moving.shape
# Out:
# /tmp/ipykernel_58631/1522653213.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   c2moving = nb.load(os.path.join(test_base_path, 'c2moving.nii')).get_data()
# (512, 512, 78)

# %%
plt.figure(figsize=(6, 6))
plt.imshow(c2moving[:, :, 34].T)
print(np.unique(c2moving))
# Out:
# [0.         0.00392157 0.00784314 0.01176471 0.01568628 0.01960784
#  0.02352941 0.02745098 0.03137255 0.03529412 0.03921569 0.04313726
#  0.04705883 0.0509804  0.05490196 0.05882353 0.0627451  0.06666667
#  0.07058824 0.07450981 0.07843138 0.08235295 0.08627451 0.09019608
#  0.09411765 0.09803922 0.10196079 0.10588236 0.10980393 0.1137255
#  0.11764707 0.12156863 0.1254902  0.12941177 0.13333334 0.13725491
#  0.14117648 0.14509805 0.14901962 0.15294119 0.15686275 0.16078432
#  0.16470589 0.16862746 0.17254903 0.1764706  0.18039217 0.18431374
#  0.18823531 0.19215687 0.19607844 0.20000001 0.20392158 0.20784315
#  0.21176472 0.21568629 0.21960786 0.22352942 0.22745099 0.23137256
#  0.23529413 0.2392157  0.24313727 0.24705884 0.25098041 0.25490198
#  0.25882354 0.26274511 0.26666668 0.27058825 0.27450982 0.27843139
#  0.28235296 0.28627453 0.2901961  0.29411766 0.29803923 0.3019608
#  0.30588237 0.30980394 0.31372551 0.31764708 0.32156865 0.32549022
# ...

# %%
c3moving = nb.load(os.path.join(test_base_path, 'c3moving.nii')).get_data()
c3moving.shape
# Out:
# /tmp/ipykernel_58631/78267534.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   c3moving = nb.load(os.path.join(test_base_path, 'c3moving.nii')).get_data()
# (512, 512, 78)

# %%
plt.figure(figsize=(6, 6))
plt.imshow(c3moving[:, :, 34].T)
print(np.unique(c3moving))
# Out:
# [0.         0.00392157 0.00784314 0.01176471 0.01568628 0.01960784
#  0.02352941 0.02745098 0.03137255 0.03529412 0.03921569 0.04313726
#  0.04705883 0.0509804  0.05490196 0.05882353 0.0627451  0.06666667
#  0.07058824 0.07450981 0.07843138 0.08235295 0.08627451 0.09019608
#  0.09411765 0.09803922 0.10196079 0.10588236 0.10980393 0.1137255
#  0.11764707 0.12156863 0.1254902  0.12941177 0.13333334 0.13725491
#  0.14117648 0.14509805 0.14901962 0.15294119 0.15686275 0.16078432
#  0.16470589 0.16862746 0.17254903 0.1764706  0.18039217 0.18431374
#  0.18823531 0.19215687 0.19607844 0.20000001 0.20392158 0.20784315
#  0.21176472 0.21568629 0.21960786 0.22352942 0.22745099 0.23137256
#  0.23529413 0.2392157  0.24313727 0.24705884 0.25098041 0.25490198
#  0.25882354 0.26274511 0.26666668 0.27058825 0.27450982 0.27843139
#  0.28235296 0.28627453 0.2901961  0.29411766 0.29803923 0.3019608
#  0.30588237 0.30980394 0.31372551 0.31764708 0.32156865 0.32549022
# ...

# %%
c4moving = nb.load(os.path.join(test_base_path, 'c4moving.nii')).get_data()
c4moving.shape
# Out:
# /tmp/ipykernel_58631/1117136353.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   c4moving = nb.load(os.path.join(test_base_path, 'c4moving.nii')).get_data()
# (512, 512, 78)

# %%
plt.figure(figsize=(6, 6))
plt.imshow(c4moving[:, :, 34].T)
print(np.unique(c4moving))
# Out:
# [0.         0.00392157 0.00784314 0.01176471 0.01568628 0.01960784
#  0.02352941 0.02745098 0.03137255 0.03529412 0.03921569 0.04313726
#  0.04705883 0.0509804  0.05490196 0.05882353 0.0627451  0.06666667
#  0.07058824 0.07450981 0.07843138 0.08235295 0.08627451 0.09019608
#  0.09411765 0.09803922 0.10196079 0.10588236 0.10980393 0.1137255
#  0.11764707 0.12156863 0.1254902  0.12941177 0.13333334 0.13725491
#  0.14117648 0.14509805 0.14901962 0.15294119 0.15686275 0.16078432
#  0.16470589 0.16862746 0.17254903 0.1764706  0.18039217 0.18431374
#  0.18823531 0.19215687 0.19607844 0.20000001 0.20392158 0.20784315
#  0.21176472 0.21568629 0.21960786 0.22352942 0.22745099 0.23137256
#  0.23529413 0.2392157  0.24313727 0.24705884 0.25098041 0.25490198
#  0.25882354 0.26274511 0.26666668 0.27058825 0.27450982 0.27843139
#  0.28235296 0.28627453 0.2901961  0.29411766 0.29803923 0.3019608
#  0.30588237 0.30980394 0.31372551 0.31764708 0.32156865 0.32549022
# ...

# %%
c5moving = nb.load(os.path.join(test_base_path, 'c5moving.nii')).get_data()
c5moving.shape
# Out:
# /tmp/ipykernel_58631/1288849597.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   c5moving = nb.load(os.path.join(test_base_path, 'c5moving.nii')).get_data()
# (512, 512, 78)

# %%
plt.figure(figsize=(6, 6))
plt.imshow(c5moving[:, :, 34].T)
print(np.unique(c5moving))
# Out:
# [0.         0.00392157 0.00784314 0.01176471 0.01568628 0.01960784
#  0.02352941 0.02745098 0.03137255 0.03529412 0.03921569 0.04313726
#  0.04705883 0.0509804  0.05490196 0.05882353 0.0627451  0.06666667
#  0.07058824 0.07450981 0.07843138 0.08235295 0.08627451 0.09019608
#  0.09411765 0.09803922 0.10196079 0.10588236 0.10980393 0.1137255
#  0.11764707 0.12156863 0.1254902  0.12941177 0.13333334 0.13725491
#  0.14117648 0.14509805 0.14901962 0.15294119 0.15686275 0.16078432
#  0.16470589 0.16862746 0.17254903 0.1764706  0.18039217 0.18431374
#  0.18823531 0.19215687 0.19607844 0.20000001 0.20392158 0.20784315
#  0.21176472 0.21568629 0.21960786 0.22352942 0.22745099 0.23137256
#  0.23529413 0.2392157  0.24313727 0.24705884 0.25098041 0.25490198
#  0.25882354 0.26274511 0.26666668 0.27058825 0.27450982 0.27843139
#  0.28235296 0.28627453 0.2901961  0.29411766 0.29803923 0.3019608
#  0.30588237 0.30980394 0.31372551 0.31764708 0.32156865 0.32549022
# ...
