# %%
import os

# %%
base_path_PD = '/w/246/gzk/PPMI/MRI_PD/PPMI'
base_path_control = '/w/246/gzk/PPMI/MRI_control/'

# %%
PD_folders = os.listdir(base_path_PD)
print(len(PD_folders), len(set(PD_folders)))
# Out:
# 640 640

# %%
for folder in PD_folders:
    tmp = os.listdir(os.path.join(base_path_PD, folder))
    for item in tmp:
        print(item)
    break
# Out:
# t2_tirm_tra_dark-fluid_NO_BLADE
# sag_mprage
# t2_cor

# %%
PD_folders
# Out:
# ['4054',
#  '3607',
#  '58671',
#  '3777',
#  '3700',
#  '40694',
#  '4124',
#  '101492',
#  '4029',
#  '107099',
#  '3403',
#  '3954',
#  '50901',
#  '3134',
#  '41382',
#  '55441',
#  '3824',
#  '3409',
#  '3504',
#  '101179',
#  '4011',
#  '42888',
#  '3308',
#  '3272',
#  '3205',
#  '4082',
#  '41410',
#  '3375',
#  '3278',
#  '3076',
#  '3001',
#  '3446',
#  '3431',
#  '3911',
#  '100842',
#  '51731',
#  '103813',
#  '56558',
#  '40541',
#  '3536',
#  '3354',
#  '3323',
#  '40713',
#  '3764',
#  '54144',
#  '3780',
#  '3224',
#  '3253',
#  '4030',
#  '74199',
#  '102293',
#  '3837',
#  '40560',
#  '3150',
#  '3127',
#  '59649',
#  '3020',
#  '55875',
#  '3584',
#  '3467',
#  '57127',
#  '4091',
#  '40366',
#  '3285',
#  '3311',
#  '3366',
#  '4075',
#  '3081',
#  '3018',
#  '3552',
#  '73935',
#  '51625',
#  '3558',
#  '3455',
#  '40558',
#  '58454',
#  '3422',
#  '3168',
#  '40012',
#  '3012',
#  '3186',
#  '3068',
#  '75524',
#  '3086',
#  '3802',
#  '40555',
#  '3522',
# ...
